# %%
final_df = process_trading_data('fii_dii_data_sep23.csv', 'processed_fii_dii_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 final_df = process_trading_data('fii_dii_data_sep23.csv', 'processed_fii_dii_data.csv')
#
# NameError: name 'process_trading_data' is not defined
